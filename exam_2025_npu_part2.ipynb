# %% [markdown]
# ### Introduction to Python and machine learning for economists (new Python users) - FINAL EXAM
#
# Date: 06/11/2025
#
# Programs: M2 APP/EADD
#
# **_PART 2 (10 points)_**

# %% [markdown]
# You are now going to use the Vahatra dataset available from the GitHub repository to perform the following tasks:
#
# 1. Upload the dataset using read_excel from openpyxl. What is the length (number of observations) in this dataset? (1 point)
# 2. Compute the deforestation rate over the period 2000-2023 in a new column. (1 point)
# 3. Create a scatter plot of the relationship between the year of first protection of each protected area (`an_creation`) and the deforestation rate that you have just computed. Include a linear fit (OLS regression line) in your plot. What do you observe? (2 points)
# 4. Split the data in a training sample and a test sample using a seed of 0 and including 30 units in the test sample. (1 point)
# 5. Train an OLS model in the training set, using `an_creation`, `pente`, `altitude`, and `dist_ville` as predictor variables. Compute the test MSE for this model. (2 points)
# 6. Repeat the same process after updating the seed used for the split to 888000. What do you observe? (1 point)
# 7. Now, compute the test MSE for the same model using LOOCV. Compare this test MSE to the two previous ones. What do you observe? Why do you think this is the case? (2 points)
